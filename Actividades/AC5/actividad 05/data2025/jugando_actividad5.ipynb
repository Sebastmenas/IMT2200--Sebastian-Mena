# %% [markdown]
# Actividad 5
#
# Importar archivos
# Lectura del archivo
#
#
# **discribe.()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
rd = pd.read_csv("spotify_history.csv")
dtos = pd.DataFrame(rd)

# %%
dtos
# Out:
#                          ts platform  ms_played conn_country  \
# 0      2022-12-29T16:39:18Z  android        753           CL
# 1      2022-12-29T16:39:19Z  android       1661           CL
# 2      2022-12-29T16:39:21Z  android       1000           CL
# 3      2022-12-29T16:39:22Z  android       1097           CL
# 4      2022-12-29T16:43:38Z  android     256920           CL
# ...                     ...      ...        ...          ...
# 41822  2025-07-13T15:18:31Z      osx      29642           CL
# 41823  2025-07-13T15:21:40Z      osx     187573           CL
# 41824  2025-07-13T15:26:51Z      osx      54677           CL
# 41825  2025-07-13T15:28:54Z      osx     122345           CL
# 41826  2025-07-15T13:45:38Z      osx          0           CL
#
#         master_metadata_track_name master_metadata_album_artist_name  \
# 0                     Warning Sign                          Coldplay
# 1                          Houdini                 Foster The People
# ...

# %% [markdown]
# Limpiar datos:

# %%
pd.isna(dtos)
#limpiar  df_reemplazado = df.replace(np.nan, 0)

limpio = dtos["ms_played"].replace(np.nan, 0)
limpio
# Out:
# 0           753
# 1          1661
# 2          1000
# 3          1097
# 4        256920
#           ...
# 41822     29642
# 41823    187573
# 41824     54677
# 41825    122345
# 41826         0
# Name: ms_played, Length: 41827, dtype: int64

# %%
dtos.columns
dtos["ts"]
# Out:
# 0        2022-12-29T16:39:18Z
# 1        2022-12-29T16:39:19Z
# 2        2022-12-29T16:39:21Z
# 3        2022-12-29T16:39:22Z
# 4        2022-12-29T16:43:38Z
#                  ...
# 41822    2025-07-13T15:18:31Z
# 41823    2025-07-13T15:21:40Z
# 41824    2025-07-13T15:26:51Z
# 41825    2025-07-13T15:28:54Z
# 41826    2025-07-15T13:45:38Z
# Name: ts, Length: 41827, dtype: object

# %%
js = dtos["ms_played"] == limpio

js
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 41822    True
# 41823    True
# 41824    True
# 41825    True
# 41826    True
# Name: ms_played, Length: 41827, dtype: bool

# %%
df = dtos.copy()


df = df.replace('*', np.nan)
df = df.replace('None', np.nan)
df = df.replace(' ', np.nan)
df = df.replace(-999, np.nan)



df
# Out:
#                          ts platform  ms_played conn_country  \
# 0      2022-12-29T16:39:18Z  android        753           CL
# 1      2022-12-29T16:39:19Z  android       1661           CL
# 2      2022-12-29T16:39:21Z  android       1000           CL
# 3      2022-12-29T16:39:22Z  android       1097           CL
# 4      2022-12-29T16:43:38Z  android     256920           CL
# ...                     ...      ...        ...          ...
# 41822  2025-07-13T15:18:31Z      osx      29642           CL
# 41823  2025-07-13T15:21:40Z      osx     187573           CL
# 41824  2025-07-13T15:26:51Z      osx      54677           CL
# 41825  2025-07-13T15:28:54Z      osx     122345           CL
# 41826  2025-07-15T13:45:38Z      osx          0           CL
#
#         master_metadata_track_name master_metadata_album_artist_name  \
# 0                     Warning Sign                          Coldplay
# 1                          Houdini                 Foster The People
# ...

# %%
df.isna()
# Out:
#           ts  platform  ms_played  conn_country  master_metadata_track_name  \
# 0      False     False      False         False                       False
# 1      False     False      False         False                       False
# 2      False     False      False         False                       False
# 3      False     False      False         False                       False
# 4      False     False      False         False                       False
# ...      ...       ...        ...           ...                         ...
# 41822  False     False      False         False                       False
# 41823  False     False      False         False                       False
# 41824  False     False      False         False                       False
# 41825  False     False      False         False                       False
# 41826  False     False      False         False                       False
#
# ...

# %%
df.columns
df.dropna(subset=['platform'])
# Out:
#                          ts platform  ms_played conn_country  \
# 0      2022-12-29T16:39:18Z  android        753           CL
# 1      2022-12-29T16:39:19Z  android       1661           CL
# 2      2022-12-29T16:39:21Z  android       1000           CL
# 3      2022-12-29T16:39:22Z  android       1097           CL
# 4      2022-12-29T16:43:38Z  android     256920           CL
# ...                     ...      ...        ...          ...
# 41822  2025-07-13T15:18:31Z      osx      29642           CL
# 41823  2025-07-13T15:21:40Z      osx     187573           CL
# 41824  2025-07-13T15:26:51Z      osx      54677           CL
# 41825  2025-07-13T15:28:54Z      osx     122345           CL
# 41826  2025-07-15T13:45:38Z      osx          0           CL
#
#         master_metadata_track_name master_metadata_album_artist_name  \
# 0                     Warning Sign                          Coldplay
# 1                          Houdini                 Foster The People
# ...

# %%
##df2['col2'] = df2['col2'].fillna(value='d')


df["ms_played"].describe()
# Out:
# count    4.182700e+04
# mean     1.899677e+05
# std      3.552166e+05
# min      0.000000e+00
# 25%      2.413300e+04
# 50%      1.673050e+05
# 75%      2.450990e+05
# max      7.932138e+06
# Name: ms_played, dtype: float64

# %%
nw =df.drop(["audiobook_title","episode_show_name"], axis =1, inplace = True)
nw
