# %% [markdown]
# # Apuntes  I1

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# ## Librerias

# %% [markdown]
# ## Lectura de Archivos

# %% [markdown]
# ## Carga de Archivos

# %% [markdown]
# ## Pandas

# %% [markdown]
# ## Matploit
